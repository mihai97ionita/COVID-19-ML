# %%
from pandas import read_csv, DataFrame
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from matplotlib import pyplot
pyplot.rcParams["figure.figsize"] = (20,10)

# %%
csv = '../../data_set2/data_agebased_map/dataset_ageBased.csv'
data = read_csv(csv, index_col=0, parse_dates=True, squeeze=True)

# %%
country_code = 'AT'

working_dataset = data[data['country_code']==country_code].copy().drop('country', axis='columns')
# ['<15yr' '15-24yr' '25-49yr' '50-64yr' '65-79yr' '80+yr']
dataset_under15 = working_dataset[working_dataset["age_group" == "<15yr"]].copy().drop('age_group', axis='columns')

working_dataset_hospital["WeekValue"].plot()
pyplot.legend(['Weekly hospital occupancy'])
pyplot.show()

working_dataset_icu = data_icu[data_icu['country']==country_code].copy().drop('country', axis='columns')
working_dataset_icu["WeekValue"].plot()
pyplot.legend(['Weekly ICU occupancy'])
pyplot.show()

working_dataset_hp_admissions = data_hp_admissions[data_hp_admissions['country']==country_code].copy().drop('country', axis='columns')
working_dataset_hp_admissions["WeekValue"].plot()
pyplot.legend(['Weekly new hospital admissions per 100k'])
pyplot.show()

working_dataset_icu_admissions = data_icu_admissions[data_icu_admissions['country']==country_code].copy().drop('country', axis='columns')
working_dataset_icu_admissions["WeekValue"].plot()
pyplot.legend(['Weekly new ICU admissions per 100k'])
pyplot.show()
